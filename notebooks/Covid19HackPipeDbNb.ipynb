# %% [markdown]
# #Notebook shortcuts
#
# ### shift+enter = Run cell and move to the next one
#
# ### ctrl+alt+P = insert cell above
# ### ctrl+alt+N = insert cell below
#
# ### ctrl+alt+up = move cell up
# ### ctrl+alt+down = move cell down
#
#
# for more shortcuts go to https://docs.microsoft.com/en-us/azure/databricks/notebooks/notebooks-use

# %% [markdown]
# # Connect to our Data Lake

# %% [markdown]
# ###Mount Points should have already been created, so that the data persists even if the cluster doesnt. This way we can easily get to the data everytime the cluster restarts.

# %%
#dbutils.fs.unmount("/mnt/coviddata")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.ls("/mnt/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.mkdirs("/mnt/coviddata/inputs")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.mkdirs("/mnt/coviddata/outputs")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.mkdirs("/mnt/coviddata/outputs")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# The below cells only work the first time, when the cluster is setup.

# %%
#dbutils.fs.mount(
#source = "wasbs://<your-container-name>@<your-storage-account-name>.blob.core.windows.net",
#mount_point = "/mnt/<mount-name>",
#extra_configs = {"fs.azure.account.key.<your-storage-account-name>.blob.core.windows.net":"<access-key>"})



#dbutils.fs.mount(
#source = "wasbs://outputs@stcovidhackoutput.blob.core.windows.net",
#mount_point = "/mnt/coviddata/outputs",
#extra_configs = {"fs.azure.account.key.stcovidhackoutput.blob.core.windows.net":"exnopN56JLbbkuZxx5VLX6sJqH7pop7fWaXEgYgMkt5OY2EtqqppFako7t3wOca7oYUbThKVwmMX4wpv4bwafA=="})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.mount(
#source = "wasbs://inputs@stcovidhackoutput.blob.core.windows.net",
#mount_point = "/mnt/coviddata/inputs",
#extra_configs = {"fs.azure.account.key.stcovidhackoutput.blob.core.windows.net":"exnopN56JLbbkuZxx5VLX6sJqH7pop7fWaXEgYgMkt5OY2EtqqppFako7t3wOca7oYUbThKVwmMX4wpv4bwafA=="})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Start here if the Lake has been previously mounted to this cluster

# %% [markdown]
# Check file structure is setup

# %%
display(dbutils.fs.ls("/mnt/coviddata/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/coviddata/inputs/</td><td>inputs/</td><td>0</td></tr><tr><td>dbfs:/mnt/coviddata/outputs/</td><td>outputs/</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# Check all the required files are visible

# %%
display(dbutils.fs.ls("/mnt/coviddata/inputs/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/coviddata/inputs/04-01-2020.csv</td><td>04-01-2020.csv</td><td>253568</td></tr><tr><td>dbfs:/mnt/coviddata/inputs/04-12-2020.csv</td><td>04-12-2020.csv</td><td>305660</td></tr><tr><td>dbfs:/mnt/coviddata/inputs/DoctorCountLatest.csv</td><td>DoctorCountLatest.csv</td><td>276136</td></tr><tr><td>dbfs:/mnt/coviddata/inputs/UID_ISO_FIPS_LookUp_Table.csv</td><td>UID_ISO_FIPS_LookUp_Table.csv</td><td>352008</td></tr><tr><td>dbfs:/mnt/coviddata/inputs/latestcovidcount.csv</td><td>latestcovidcount.csv</td><td>311180</td></tr></tbody></table></div>

# %% [markdown]
# #Wrangle the Doctor Data

# %%
filepath2="/mnt/coviddata/inputs/DoctorCountLatest.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###Infer the schema and load the data to a spark data frame.
# ### Cache the data for faster operations

# %%
doctorraw = spark.read.format('csv').options(header='false', inferSchema='true').load(filepath2)
doctorraw.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: DataFrame[_c0: int, _c1: string, _c2: string, _c3: string, _c4: string, _c5: int, _c6: string, _c7: string, _c8: string, _c9: string, _c10: string, _c11: string, _c12: string, _c13: string, _c14: double, _c15: double, _c16: string, _c17: string, _c18: string, _c19: string]</div>

# %% [markdown]
# ### Check if schema was inferred correctly

# %%
doctorraw.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- _c1: string (nullable = true)
# -- _c2: string (nullable = true)
# -- _c3: string (nullable = true)
# -- _c4: string (nullable = true)
# -- _c5: integer (nullable = true)
# -- _c6: string (nullable = true)
# -- _c7: string (nullable = true)
# -- _c8: string (nullable = true)
# -- _c9: string (nullable = true)
# -- _c10: string (nullable = true)
# -- _c11: string (nullable = true)
# -- _c12: string (nullable = true)
# -- _c13: string (nullable = true)
# -- _c14: double (nullable = true)
# -- _c15: double (nullable = true)
# -- _c16: string (nullable = true)
# -- _c17: string (nullable = true)
# -- _c18: string (nullable = true)
# -- _c19: string (nullable = true)
#
# </div>

# %% [markdown]
# ### Display the data in a nice readable format

# %%
display(doctorraw)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th><th>_c8</th><th>_c9</th><th>_c10</th><th>_c11</th><th>_c12</th><th>_c13</th><th>_c14</th><th>_c15</th><th>_c16</th><th>_c17</th><th>_c18</th><th>_c19</th></tr></thead><tbody><tr><td>22092804</td><td>HWF_0001</td><td>COUNTRY</td><td>AGO</td><td>YEAR</td><td>1997</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.592</td><td>0.592</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092805</td><td>HWF_0001</td><td>COUNTRY</td><td>AGO</td><td>YEAR</td><td>2004</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.621</td><td>0.621</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092806</td><td>HWF_0001</td><td>COUNTRY</td><td>AGO</td><td>YEAR</td><td>2009</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1.313</td><td>1.313</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092807</td><td>HWF_0001</td><td>COUNTRY</td><td>AGO</td><td>YEAR</td><td>2017</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2.146</td><td>2.146</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092808</td><td>HWF_0001</td><td>COUNTRY</td><td>BDI</td><td>YEAR</td><td>2004</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.28</td><td>0.28</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092809</td><td>HWF_0001</td><td>COUNTRY</td><td>BDI</td><td>YEAR</td><td>2010</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.482</td><td>0.482</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092810</td><td>HWF_0001</td><td>COUNTRY</td><td>BDI</td><td>YEAR</td><td>2011</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.399</td><td>0.399</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092811</td><td>HWF_0001</td><td>COUNTRY</td><td>BDI</td><td>YEAR</td><td>2012</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.539</td><td>0.539</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092812</td><td>HWF_0001</td><td>COUNTRY</td><td>BDI</td><td>YEAR</td><td>2013</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.581</td><td>0.581</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092813</td><td>HWF_0001</td><td>COUNTRY</td><td>BDI</td><td>YEAR</td><td>2014</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.619</td><td>0.619</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092814</td><td>HWF_0001</td><td>COUNTRY</td><td>BDI</td><td>YEAR</td><td>2015</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.5</td><td>0.5</td><td>null</td><td>null</td><td>null</td><td>2020-02-12 09:20:25.0000000 +00:00</td></tr><tr><td>22092815</td><td>HWF_0001</td><td>COUNTRY</td><td>BDI</td><td>YEAR</td><td>2017</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td> ...

# %% [markdown]
# ### focus on the columns we want to work with

# %%
display(doctorraw.select("_c3","_c5","_c15"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c3</th><th>_c5</th><th>_c15</th></tr></thead><tbody><tr><td>AGO</td><td>1997</td><td>0.592</td></tr><tr><td>AGO</td><td>2004</td><td>0.621</td></tr><tr><td>AGO</td><td>2009</td><td>1.313</td></tr><tr><td>AGO</td><td>2017</td><td>2.146</td></tr><tr><td>BDI</td><td>2004</td><td>0.28</td></tr><tr><td>BDI</td><td>2010</td><td>0.482</td></tr><tr><td>BDI</td><td>2011</td><td>0.399</td></tr><tr><td>BDI</td><td>2012</td><td>0.539</td></tr><tr><td>BDI</td><td>2013</td><td>0.581</td></tr><tr><td>BDI</td><td>2014</td><td>0.619</td></tr><tr><td>BDI</td><td>2015</td><td>0.5</td></tr><tr><td>BDI</td><td>2017</td><td>1.001</td></tr><tr><td>BEN</td><td>2004</td><td>0.401</td></tr><tr><td>BEN</td><td>2008</td><td>0.623</td></tr><tr><td>BEN</td><td>2010</td><td>0.558</td></tr><tr><td>BEN</td><td>2011</td><td>0.577</td></tr><tr><td>BEN</td
><tr><td>COG</td><td>2011</td><td>1.645</td></tr><tr><td>COM</td><td>2004</td><td>1.926</td></tr><tr><td>COM</td><td>2005</td><td>1.897</td></tr><tr><td>COM</td><td>2009</td><td>1.901</td></tr><tr><td>COM</td><td>2012</td><td>1.699</td></tr><tr><td>COM</td><td>2016</td><td>2.715</td></tr><tr><td>CPV</td><td>2009</td><td>5.157</td></tr><tr><td>CPV</td><td>2010</td><td>5.928</td></tr><tr><td>CPV</td><td>2011</td><td>5.853</td></tr><tr><td>CPV</td><td>2012</td><td>5.146</td></t ...

# %%
doctorraw.select("_c3","_c5","_c15").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----+-----+
# _c3| _c5| _c15|
# +---+----+-----+
# AGO|1997|0.592|
# AGO|2004|0.621|
# AGO|2009|1.313|
# AGO|2017|2.146|
# BDI|2004| 0.28|
# BDI|2010|0.482|
# BDI|2011|0.399|
# BDI|2012|0.539|
# BDI|2013|0.581|
# BDI|2014|0.619|
# BDI|2015|  0.5|
# BDI|2017|1.001|
# BEN|2004|0.401|
# BEN|2008|0.623|
# BEN|2010|0.558|
# BEN|2011|0.577|
# BEN|2012|1.646|
# BEN|2013|1.849|
# BEN|2016|0.481|
# BEN|2018|0.791|
# +---+----+-----+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### filter the data so that there is only the doctor per 10k count for the most recent year for each country in the list. We only need the latest year.

# %%
doctorlatest=doctorraw.groupBy("_c3").max("_c5","_c15")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### just confirm that Australia exists in the data set we're pulling

# %%
doctorlatest.filter("_c3= 'AUS'").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------+---------+
# _c3|max(_c5)|max(_c15)|
# +---+--------+---------+
# AUS|    2017|   36.778|
# +---+--------+---------+
#
# </div>

# %%
display(doctorlatest)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c3</th><th>max(_c5)</th><th>max(_c15)</th></tr></thead><tbody><tr><td>NIU</td><td>2008</td><td>23.529</td></tr><tr><td>HTI</td><td>2018</td><td>2.384</td></tr><tr><td>BRB</td><td>2017</td><td>24.843</td></tr><tr><td>LVA</td><td>2017</td><td>46.934</td></tr><tr><td>POL</td><td>2017</td><td>24.188</td></tr><tr><td>ZMB</td><td>2018</td><td>11.867</td></tr><tr><td>JAM</td><td>2017</td><td>13.061</td></tr><tr><td>BRA</td><td>2018</td><td>21.652</td></tr><tr><td>ARM</td><td>2017</td><td>44.023</td></tr><tr><td>MOZ</td><td>2018</td><td>0.838</td></tr><tr><td>CUB</td><td>2018</td><td>84.218</td></tr><tr><td>JOR</td><td>2017</td><td>28.078</td></tr><tr><td>SOM</td><td>2014</td><td>0.279</td></tr><tr><td>FRA</td><td>2018</td><td>34.41</td></tr><tr><td>COD</td><td>2016</td><td>0.934</td></tr><tr><td>BRN</td><td>2017</td><td>17.812</td></tr><tr><td>FSM</td><td>2009</td><td>6.184</td></tr><tr><td>BOL</td><td>2016</td><td>15.901</td></tr><tr><td>URY</td><td>2017</td><td>50.794</td></tr><tr><td>LBY</td><td>2017</td><td>20.905</td></tr><tr><td>ETH</td><td>2018</td><td>0.986</td></tr><tr><td>ATG</td><td>2017</td><td>29.56</td></tr><tr><td>GNQ</td><td>2017</td><td>4.017</td></tr><tr><td>ITA</td><td>2018</td><td>59.882</td

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
doctorlatest.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- COUNTRY: string (nullable = true)
# -- YEAR: integer (nullable = true)
# -- DoctorsPer10k: double (nullable = true)
#
# </div>

# %%
doctorlatest.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- COUNTRY: string (nullable = true)
# -- YEAR: integer (nullable = true)
# -- DoctorsPer10k: double (nullable = true)
#
# </div>

# %% [markdown]
# ### save it to csv on our data lake

# %%
doctorlatest.write.mode('overwrite').option("header","true").csv('/mnt/coviddata/outputs/DoctorCountLatestYear')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###Load the country code data

# %%
filepath3="/mnt/coviddata/inputs/UID_ISO_FIPS_LookUp_Table.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
countrycodes = spark.read.format('csv').options(header='true', inferSchema='true').load(filepath3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
countrycodes.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- UID: integer (nullable = true)
# -- iso2: string (nullable = true)
# -- iso3: string (nullable = true)
# -- code3: integer (nullable = true)
# -- FIPS: integer (nullable = true)
# -- Admin2: string (nullable = true)
# -- Province_State: string (nullable = true)
# -- Country_Region: string (nullable = true)
# -- Lat: double (nullable = true)
# -- Long_: double (nullable = true)
# -- Combined_Key: string (nullable = true)
# -- Population: integer (nullable = true)
#
# </div>

# %%
countrycodes.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----+----+-----+----+------+--------------+-------------------+---------+----------+-------------------+----------+
# UID|iso2|iso3|code3|FIPS|Admin2|Province_State|     Country_Region|      Lat|     Long_|       Combined_Key|Population|
# +---+----+----+-----+----+------+--------------+-------------------+---------+----------+-------------------+----------+
#   4|  AF| AFG|    4|null|  null|          null|        Afghanistan| 33.93911| 67.709953|        Afghanistan|  38928341|
#   8|  AL| ALB|    8|null|  null|          null|            Albania|  41.1533|   20.1683|            Albania|   2877800|
#  12|  DZ| DZA|   12|null|  null|          null|            Algeria|  28.0339|    1.6596|            Algeria|  43851043|
#  20|  AD| AND|   20|null|  null|          null|            Andorra|  42.5063|    1.5218|            Andorra|     77265|
#  24|  AO| AGO|   24|null|  null|          null|             Angola| -11.2027|   17.8739|             Angola|  32866268|
#  28|  AG| ATG|   28|null|  null|          null|Antigua and Barbuda|  17.0608|  -61.7964|Antigua and Barbuda|     97928|
#  32|  AR| ARG|   32|null|  null|          null|          Argentina| -38.4161|  -63.6167|          Argentina|  45195777|
#  51|  AM| ARM|   51|null|  null|          null|            Armenia|  40.0691|   45.0382|            Armenia|   2963234|
#  40|  AT| AUT|   40|null|  null|          null|            Austria|  47.5162|   14.5501|            Austria|   9006400|
#  31|  AZ| AZE|   31|null|  null|          null|         Azerbaijan|  40.1431|   47.5769|         Azerbaijan|  10139175|
#  44|  BS| BHS|   44|null|  null|          null|            Bahamas|25.025885|-78.035889|            Bahamas|    393248|
#  48|  BH| BHR|   48|null|  null|          null|            Bahrain|  26.0275|     50.55|            Bahrain|   1701583|
#  50|  BD| BGD|   50|null|  null|          null|         Bangladesh|   23.685|   90.3563|         Bangladesh| 164689383|
#  52|  BB| BRB|   52|null|  null|          null|           Barbados|  13.1939|  -59.5432|           Barbados|    287371|
# 112|  BY| BLR|  112|null|  null|          null|            Belarus|  53.7098|   27.9534|            Belarus|   9449321|
#  56|  BE| BEL|   56|null|  null|          null|            Belgium|  50.8333|  4.469936|            Belgium|  11589616|
#  84|  BZ| BLZ|   84|null|  null|          null|             Belize|  17.1899|  -88.4976|             Belize|    397621|
# 204|  BJ| BEN|  204|null|  null|          null|              Benin|   9.3077|    2.3158|              Benin|  12123198|
#  64|  BT| BTN|   64|null|  null|          null|             Bhutan|  27.5142|   90.4336|             Bhutan|    771612|
#  68|  BO| BOL|   68|null|  null|          null|            Bolivia| -16.2902|  -63.5887|            Bolivia|  11673029|
# +---+----+----+-----+----+------+--------------+-------------------+---------+----------+-------------------+----------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### just want country region and iso3

# %%
countrycodeiso3=countrycodes.select("iso3","Country_Region").distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
countrycodeiso3.filter("iso3='AUS'").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------+
# iso3|Country_Region|
# +----+--------------+
#  AUS|     Australia|
# +----+--------------+
#
# </div>

# %%
countrycodeiso3.write.mode('overwrite').csv('/mnt/coviddata/outputs/CountryCodesISO3')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #Wrangle the COVID Data
#
# ### load the covid data and summarize by country
# ### join the summarized data with the count of doctors and country codes

# %%
# Creating widgets for leveraging parameters, and printing the parameters

dbutils.widgets.text("input", "","")
y = dbutils.widgets.get("input")
print ("Param -\'input':")
print (y)

dbutils.widgets.text("fileDate", "","")
z = dbutils.widgets.get("fileDate")
print ("Param -\'fileDate':")
print (z)

dbutils.widgets.text("name", "","")
u = dbutils.widgets.get("name")
print ("Param -\'name':")
print (u)

dbutils.widgets.text("name2", "","")
v = dbutils.widgets.get("name2")
print ("Param -\'name2':")
print (v)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Param -&#39;input&#39;:
#
# Param -&#39;fileDate&#39;:
#
# Param -&#39;name&#39;:
#
# Param -&#39;name2&#39;:
#
# </div>

# %%
filepath = "/mnt/coviddata/inputs/latestcovidcount.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### infer the schema and load the data into a spark dataframe

# %%
covidraw = spark.read.format('csv').options(header='true', inferSchema='true').load(filepath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(covidraw)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>FIPS</th><th>Admin2</th><th>Province_State</th><th>Country_Region</th><th>Last_Update</th><th>Lat</th><th>Long_</th><th>Confirmed</th><th>Deaths</th><th>Recovered</th><th>Active</th><th>Combined_Key</th></tr></thead><tbody><tr><td>45001</td><td>Abbeville</td><td>South Carolina</td><td>US</td><td>2020-04-14T23:33:31.000+0000</td><td>34.22333378</td><td>-82.46170658</td><td>9</td><td>0</td><td>0</td><td>9</td><td>Abbeville, South Carolina, US</td></tr><tr><td>22001</td><td>Acadia</td><td>Louisiana</td><td>US</td><td>2020-04-14T23:33:31.000+0000</td><td>30.295064899999996</td><td>-92.41419698</td><td>104</td><td>5</td><td>0</td><td>99</td><td>Acadia, Louisiana, US</td></tr><tr><td>51001</td><td>Accomack</td><td>Virginia</td><td>US</td><td>2020-04-14T23:33:31.000+0000</td><td>37.76707161</td><td>-75.63234615</td><td>15</td><td>0</td><td>0</td><td>15</td><td>Accomack, Virginia, US</td></tr><tr><td>16001</td><td>Ada</td><td>Idaho</td><td>US</td><td>2020-04-14T23:33:31.000+0000</td><td>43.4526575</td><td>-116.24155159999998</td><td>538</td><td>9</td><td>0</td><td>529</td><td>Ada, Idaho, US</td></tr><tr><td>19001</td><td>Adair</td><td>Iowa</td><td>US</td><td>2020-04-14T23:33:31.000+0000</td><td
td><td>4</td><td>0</td><td>0</td></tr><tr><td>Somalia</td><td>60</td><td>2</td><td>2</td></tr><tr><td>Chile</td><td>7917</td><td>92</td><td>2646</td></tr><tr><td>Croatia</td><td>1704</td><td>31</td><td>415</td></tr><tr><td>Burundi</td><td>5</td><td>1</td><td>0</td></tr><tr><td>Andorra</td><td>659</td><td>31</td><td>128</td></tr><tr><td>Bolivia</td><td>3 ...

# %%
#covidlatest.write.mode('overwrite').csv('/mnt/coviddata/outputs/CovidLatest')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
doctorlatest.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----+-------------+
# COUNTRY|YEAR|DoctorsPer10k|
# +-------+----+-------------+
#     NIU|2008|       23.529|
#     HTI|2018|        2.384|
#     BRB|2017|       24.843|
#     LVA|2017|       46.934|
#     POL|2017|       24.188|
#     ZMB|2018|       11.867|
#     JAM|2017|       13.061|
#     BRA|2018|       21.652|
#     ARM|2017|       44.023|
#     MOZ|2018|        0.838|
#     CUB|2018|       84.218|
#     JOR|2017|       28.078|
#     SOM|2014|        0.279|
#     FRA|2018|        34.41|
#     COD|2016|        0.934|
#     BRN|2017|       17.812|
#     FSM|2009|        6.184|
#     BOL|2016|       15.901|
#     URY|2017|       50.794|
#     LBY|2017|       20.905|
# +-------+----+-------------+
# only showing top 20 rows
#
# </div>

# %%
countrycodeiso3.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+------------------+
# iso3|    Country_Region|
# +----+------------------+
#  GNQ| Equatorial Guinea|
#  LBY|             Libya|
#  ASM|                US|
#  HTI|             Haiti|
#  AUT|           Austria|
#  PYF|            France|
#  ECU|           Ecuador|
#  JAM|           Jamaica|
#  RWA|            Rwanda|
#  UZB|        Uzbekistan|
#  DOM|Dominican Republic|
#  MEX|            Mexico|
#  LBR|           Liberia|
#  BMU|    United Kingdom|
#  COL|          Colombia|
#  YEM|             Yemen|
#  GMB|            Gambia|
#  ZWE|          Zimbabwe|
#  SVN|          Slovenia|
#  SUR|          Suriname|
# +----+------------------+
# only showing top 20 rows
#
# </div>

# %%
from pyspark.sql.functions import col
doctoriso3=doctorlatest.join(countrycodeiso3,col("COUNTRY")==col("iso3"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
doctoriso3.select("COUNTRY","YEAR","DoctorsPer10k","Country_Region").filter("COUNTRY = 'AUS'").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----+-------------+--------------+
# COUNTRY|YEAR|DoctorsPer10k|Country_Region|
# +-------+----+-------------+--------------+
#     AUS|2017|       36.778|     Australia|
# +-------+----+-------------+--------------+
#
# </div>

# %%
coviddoctors = covidlatest.join(doctoriso3, doctoriso3.Country_Region == covidlatest.Country_Region)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
coviddoctors.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+--------------+-----------+--------------+-------+----+-------------+----+------------------+
#     Country_Region|sum(Confirmed)|sum(Deaths)|sum(Recovered)|COUNTRY|YEAR|DoctorsPer10k|iso3|    Country_Region|
# +------------------+--------------+-----------+--------------+-------+----+-------------+----+------------------+
#  Equatorial Guinea|            41|          0|             4|    GNQ|2017|        4.017| GNQ| Equatorial Guinea|
#              Libya|            35|          1|             9|    LBY|2017|       20.905| LBY|             Libya|
#              Haiti|            40|          3|             0|    HTI|2018|        2.384| HTI|             Haiti|
#            Austria|         14226|        384|          7633|    AUT|2017|       51.697| AUT|           Austria|
#            Ecuador|          7603|        369|           696|    ECU|2016|       21.111| ECU|           Ecuador|
#            Jamaica|            73|          4|            19|    JAM|2017|       13.061| JAM|           Jamaica|
#             Rwanda|           134|          0|            49|    RWA|2018|        1.371| RWA|            Rwanda|
#         Uzbekistan|          1165|          4|            99|    UZB|2014|       33.911| UZB|        Uzbekistan|
# Dominican Republic|          3286|        183|           162|    DOM|2011|       18.498| DOM|Dominican Republic|
#             Mexico|          5014|        332|          1964|    MEX|2017|       23.827| MEX|            Mexico|
#            Liberia|            59|          6|             4|    LBR|2015|        0.376| LBR|           Liberia|
#           Colombia|          2979|        127|           354|    COL|2018|       21.848| COL|          Colombia|
#              Yemen|             1|          0|             0|    YEM|2014|        5.251| YEM|             Yemen|
#             Gambia|             9|          1|             2|    GMB|2015|        1.109| GMB|            Gambia|
#           Zimbabwe|            17|          3|             0|    ZWE|2018|        2.096| ZWE|          Zimbabwe|
#           Slovenia|          1220|         56|           152|    SVN|2017|       30.861| SVN|          Slovenia|
#           Suriname|            10|          1|             6|    SUR|2018|       12.101| SUR|          Suriname|
#             Serbia|          4465|         94|             0|    SRB|2016|       31.131| SRB|            Serbia|
#            Bahamas|            49|          8|             6|    BHS|2017|       27.553| BHS|           Bahamas|
#           Slovakia|           835|          2|           113|    SVK|2017|       34.664| SVK|          Slovakia|
# +------------------+--------------+-----------+--------------+-------+----+-------------+----+------------------+
# only showing top 20 rows
#
# </div>

# %%
coviddoctorselect = coviddoctors.select(covidlatest.Country_Region,"sum(Confirmed)","sum(Deaths)","sum(Recovered)","COUNTRY","YEAR","DoctorsPer10k")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
coviddoctorfinal=coviddoctorselect\
.withColumnRenamed('sum(Confirmed)','Confirmed')\
.withColumnRenamed('sum(Deaths)','Deaths')\
.withColumnRenamed('sum(Recovered)','Recovered')\
.withColumnRenamed('COUNTRY','Iso3')\
.withColumnRenamed('YEAR','YearOfDoctorCount')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
coviddoctorfinal.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Country_Region: string (nullable = true)
# -- Confirmed: long (nullable = true)
# -- Deaths: long (nullable = true)
# -- Recovered: long (nullable = true)
# -- Iso3: string (nullable = true)
# -- YearOfDoctorCount: integer (nullable = true)
# -- DoctorsPer10k: double (nullable = true)
#
# </div>

# %%
coviddoctorfinal.write.mode("overwrite").option("header", "true").csv("/mnt/coviddata/outputs/CovidDoctorCombined")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.mkdirs("/mnt/coviddata/outputs/final")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[60]: True</div>

# %% [markdown]
# ### for the data factory to correctly copy these shards to Synapse, we need to remove any unneeded files from the output directory. Since trying to find files that begin with "_" seem to throw java, we will look for all the .csv files and move them to a clean directory and then point the factory to that as the source

# %%
# %scala

val fileprefix= "/mnt/coviddata/outputs/final/"
val partition_path = dbutils.fs.ls("/mnt/coviddata/outputs/CovidDoctorCombined")
     .filter(file=>file.name.endsWith("csv"))//(0).path

partition_path.foreach { file => dbutils.fs.cp(file.path,fileprefix+file.name)}

//partition_path.show()

//partition_path.toDF().foreach { file => dbutils.fs.cp(file(0).toString,)}//.toString, true)}


//dbutils.fs.cp(partition_path,fileprefix+".tab")

//dbutils.fs.rm(fileprefix+".tmp",recurse=true)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout